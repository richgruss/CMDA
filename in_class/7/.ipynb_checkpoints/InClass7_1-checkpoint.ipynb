# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import random

#read bicycle data into pandas dataframe:  see https://www.kaggle.com/c/bike-sharing-demand
bike_data = pd.read_csv('/Users/rgruss/git/CMDA/final_project/bicycle_data.csv')

#10,000 rows is too hard to visualize.  Take random 100 subset
rows = np.random.choice(bike_data.index.values, 100)
bike_data_sampled = bike_data.ix[rows]
bike_data_sampled.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 10380  11/17/12 22:00       4        0           0        2  13.12  16.665
# 2068     5/13/11 2:00       2        0           1        2  20.50  24.240
# 7309     5/3/12 22:00       2        0           1        1  25.42  29.545
# 1067      3/9/11 0:00       1        0           1        1  10.66  14.395
# 7115    4/14/12 20:00       2        0           0        2  22.96  26.515
#
#        humidity  windspeed  casual  registered  count
# 10380        57     7.0015      15         130    145
# 2068         88     8.9981       3           8     11
# 7309         78     0.0000      29         217    246
# 1067         65     6.0032       0           9      9
# 7115         46     8.9981     112         209    321

# %%
plt.hist(bike_data_sampled['registered'], bins=10, color='b', alpha=.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-8c973738d967> in <module>()
# ----> 1 plt.hist(bike_data_sampled['registered'], bins=10, color='b', alpha=.5)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, hold, **kwargs)
#    2339         ax.hold(hold)
#    2340     try:
# -> 2341         ret = ax.hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    2342         draw_if_interactive()
#    2343     finally:
#
# ...

# %%
bike_data_sampled['registered'].plot(kind='kde')

# %%
bike_data_sampled['season'].plot(kind='bar')

# %%
fig = plt.scatter(bike_data_sampled['temp'], bike_data_sampled['count'])

# %%
fig.
